# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("dataFiles/employees.csv")
print(data)
# Out:
#    YearsExperience   Salary
# 0              1.1    39843
# 1              2.0    42332
# 2              2.1    41000
# 3              3.5    45843
# 4              3.6    46843
# 5              4.1    48843
# 6              4.2    46843
# 7              5.1    51843
# 8              6.1    55843

# %%
X = data.iloc[:, 0]
y = data.iloc[:, 1]

mean_X = X.mean()
std_X = X.std()
X = (X - mean_X) / std_X

# Standardization for y
mean_y = y.mean()
std_y = y.std()
y = (y - mean_y) / std_y

plt.scatter(X, y)
plt.show()

# %%
m = 0 
c = 0 
learning_rate = 0.1
epochs = 1000

for i in range(epochs):
    y_pred = m * X + c 
    grad_m = (-2 / len(X)) * sum(X * (y - y_pred))
    grad_c = (-2 / len(X)) * sum(y - y_pred)
    m -= learning_rate * grad_m
    c -= learning_rate * grad_c

print("Slope (m):", m)
print("Intercept (c):", c)
# Out:
# Slope (m): 0.9816275810746805
# Intercept (c): -1.838035896323869e-16

# %%
plt.scatter(X, y) 
plt.plot(X, y_pred, color='red')  # regression line
plt.show()
